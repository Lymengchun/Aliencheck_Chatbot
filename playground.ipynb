# %%
#run api
#uvicorn app:app --reload

# %% [markdown]
# ### Install library ###

# %%
# %pip install ollama chromadb langchain_community pypdf fastapi uvicorn
# Out:
# Requirement already satisfied: ollama in /usr/local/lib/python3.10/site-packages (0.5.4)
# Requirement already satisfied: chromadb in /usr/local/lib/python3.10/site-packages (1.0.21)
# Requirement already satisfied: langchain_community in /usr/local/lib/python3.10/site-packages (0.3.29)
# Requirement already satisfied: pypdf in /usr/local/lib/python3.10/site-packages (6.0.0)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.10/site-packages (0.116.1)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.10/site-packages (0.35.0)
# Requirement already satisfied: httpx>=0.27 in /usr/local/lib/python3.10/site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /usr/local/lib/python3.10/site-packages (from ollama) (2.11.9)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in /usr/local/lib/python3.10/site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/site-packages (from chromadb) (2.2.6)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /usr/local/lib/python3.10/site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/lymeng/Library/Python/3.10/lib/python/site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.10/site-packages (from chromadb) (1.22.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.10/site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.10/site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.10/site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/site-packages (from chromadb) (0.22.0)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.10/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.10/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/site-packages (from chromadb) (1.74.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.10/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/site-packages (from chromadb) (0.17.4)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.10/site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.10/site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.10/site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.10/site-packages (from chromadb) (3.11.3)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/site-packages (from chromadb) (14.1.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.10/site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: requests<3.0,>=2.7 in /usr/local/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.5 in /Users/lymeng/Library/Python/3.10/lib/python/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /Users/lymeng/Library/Python/3.10/lib/python/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.8.3)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.75 in /usr/local/lib/python3.10/site-packages (from langchain_community) (0.3.76)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in /usr/local/lib/python3.10/site-packages (from langchain_community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/site-packages (from langchain_community) (2.0.43)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/site-packages (from langchain_community) (3.12.15)
# Requirement already satisfied: dataclasses-json<0.7,>=0.6.7 in /usr/local/lib/python3.10/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.10/site-packages (from langchain_community) (2.10.1)
# Requirement already satisfied: langsmith>=0.1.125 in /usr/local/lib/python3.10/site-packages (from langchain_community) (0.4.28)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.10/site-packages (from langchain_community) (0.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.6.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.10/site-packages (from langchain<2.0.0,>=0.3.27->langchain_community) (0.3.11)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain_community) (1.33)
# Requirement already satisfied: packaging>=23.2 in /Users/lymeng/Library/Python/3.10/lib/python/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain_community) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<2.0.0,>=0.3.75->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.10/site-packages (from pydantic>=2.9->ollama) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.10/site-packages (from pydantic>=2.9->ollama) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.1.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain_community) (1.1.0)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in /usr/local/lib/python3.10/site-packages (from fastapi) (0.47.3)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.10/site-packages (from starlette<0.48.0,>=0.40.0->fastapi) (4.10.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/lymeng/Library/Python/3.10/lib/python/site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (1.3.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/site-packages (from uvicorn) (8.2.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (2.2.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (0.27.1)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.10/site-packages (from langsmith>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.10/site-packages (from langsmith>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (6.32.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /usr/local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /usr/local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.10/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.58b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/lymeng/Library/Python/3.10/lib/python/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/site-packages (from tokenizers>=0.13.2->chromadb) (0.34.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.1.10)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: /usr/local/opt/python@3.10/bin/python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import ###

# %%
import ollama
import chromadb
import os
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.embeddings import OllamaEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.llms import Ollama

# %% [markdown]
# ### Initial Ollama model ###

# %%
llm = Ollama(model="llama3.2")  # Or other model
# Out:
# /var/folders/_9/9dhg2c4936l9jm__n1bk4kdc0000gn/T/ipykernel_7872/746353989.py:1: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="llama3.2")  # Or other model

# %% [markdown]
# ### Read PDF ###

# %%
folder_path = "data"  # Change to your folder path
text = ""
doc = []
for filename in os.listdir(folder_path):
    if filename.lower().endswith(".pdf"):
        pdf_path = os.path.join(folder_path, filename)
        print("reading ",pdf_path)
        reader = PyPDFLoader(pdf_path)
    
        pages = reader.load()
        # doc.extend(reader.load())
        for page in pages:
            text += page.page_content + "\n"
            # print(f"{doc[0].page_content}")
            # print(f"text:",text)
# Out:
# reading  data/iot-leaflet-v10-en.pdf

# %%
text_path = os.path.join(folder_path, "khmer_text.txt")
with open(text_path, "r", encoding="utf-8") as f:
    text = f.read()

print(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 text_path = os.path.join(folder_path, "khmer_text.txt")
#       2 with open(text_path, "r", encoding="utf-8") as f:
#       3     text = f.read()
#
# NameError: name 'os' is not defined

# %% [markdown]
# ### Split into smaller chunks ###

# %%
# 2. Split into smaller chunks
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
730845451355, -0.25380274653434753, 0.7523647546768188, -0.750005841255188, 0.08527834713459015, -0.30092260241508484, -0.030766919255256653, 0.09112296998500824, 0.7433755993843079, 0.31408289074897766, 0.1635715365409851, -0.155752494931221, 0.6647266745567322, 0.21391187608242035, -1.044511318206787, 1.068281650543213, 0.022028082981705666, 0.2806551456451416, 1.24342942237854, 0.1870439350605011, 0.7214586734771729, 0.39316296577453613, 0.7760032415390015, -1.2960622310638428, -0.3886059522628784, 0.02628287672996521, -0.055915430188179016, -0.7554844617843628, 0.5591708421707153, 0.07976989448070526, 0.2605104446411133, 0.6774921417236328, -0.3127214312553406, 0.13066282868385315, -0.052343446761369705, -0.11904343962669373, 0.5575234293937683, -0.8038137555122375, 0.7253919243812561, -0.07660537958145142, 0.630868673324585, -0.3450253903865814, 0.45912766456604004, 0.7045831084251404, -0.5871496200561523, 0.15895070135593414, -0.1497947871685028, -0.6272664666175842, 0.9395046234130859, 0.7931656837463379, 1.052787184715271, 0.11648009717464447, -0.5552748441696167, 0.6436135768890381, 0.8942272663116455, -0.251739501953125, 0.25537511706352234, -0.23075491189956665, 0.45606881380081177, 0.5540568828582764, 0.46832042932510376, -0.30802175402641296, 0.18950137495994568, -0.6613399982452393, -0.15732672810554504, -0.2692911326885223 ...

# %% [markdown]
# ### Initialize ChromaDB ###

# %%
client = chromadb.PersistentClient(path="./chroma_db")
collection = client.get_or_create_collection(name="pdf_docs")

# %% [markdown]
# ### Store in ChromaDB ###

# %%
vectors = [embeddings.embed_query(chunk) for chunk in docs]
ids = [str(i) for i in range(len(docs))]
metadatas = [
    {"title": "khmer_text", "type": "txt", "chunk_index": i}
    for i in range(len(docs))
]

collection.add(
    embeddings=vectors,
    documents=docs,
    metadatas=metadatas,
    ids=ids,
)

# %%
#search in chromadb
question = ""
q_vector = embeddings.embed_query(question)
print(q_vector)
results = collection.query(
    query_embeddings=[q_vector],
    n_results=3
)
print(results)
# Out:
# [0.06161545589566231, 0.27872204780578613, -0.5239893198013306, 0.8287005424499512, -0.7302275896072388, -0.3845903277397156, 0.06885894387960434, 0.2874869406223297, 0.199640154838562, 0.003152400255203247, 0.02832014113664627, 0.788447916507721, -0.11683638393878937, 0.28650185465812683, -0.9586089253425598, 0.42641186714172363, 0.3532472848892212, -0.13316896557807922, -1.0392723083496094, 0.28765052556991577, -0.6271764039993286, -0.026553090661764145, -1.0619559288024902, -0.6783238649368286, -0.25833630561828613, 0.3143206238746643, -0.4371732175350189, -0.6914133429527283, 0.7145335674285889, 0.9485552310943604, 0.1778549998998642, -0.184513658285141, 0.339548796415329, -0.3821694850921631, 0.19049949944019318, -0.44373393058776855, 0.5176495313644409, -0.7122499942779541, -0.5138477683067322, -0.19765037298202515, -0.09576530009508133, 0.8037701845169067, 0.7702277898788452, -1.109739899635315, -0.6688625812530518, 0.3161863088607788, 0.16511079668998718, -0.3203842043876648, -0.15086880326271057, -0.3633584976196289, -0.8563293218612671, -0.1157490536570549, 0.061205558478832245, 0.
# {'ids': [['ec122932', 'ec122874', 'ec122978']], 'embeddings': None, 'documents': [['Applic ation\nKey Feature s\nAlarm Notiﬁcation\nTechn ical Speciﬁc ation\nInput  Volta ge\n200 to 240 (VAC),    10%\nOpe ration Temper ature Ran ge\n0 ºC - 65 ºC\nFre quenc y\n50Hz\nCommunic ation\nIns tallat ion \nIndoor\nWiﬁ 2.4GHz, Protocol 802.11 b/g/n\nSAFETY & SECURITY\nMODERN & COMFORT\nCOMSUMPTION\nOPERATION & MAINTENANCE\nThe VH-003 is a VP.Start IoT solution designed to interact with AlienCheck App \nwhich will provide users with night light that can aid relaxation before bed, reduce', 'Input  Volta ge\n200 to 240 (VAC),    10%\nFre quenc y\n50Hz\nOutput  Voltag e\n200 to 240 (VAC),    10%\nIns tallat ion \nOpe ration Temper ature Ran ge\n0 ºC - 65 ºC\nIndoor\nCommunic ation\nWiﬁ 2.4GHz, Protocol 802.11 b/g/n\nSAFETY & SECURITY\nMODERN & COMFORT\nCOMSUMPTION\nOPERATION & MAINTENANCE\nVH-001\nThe VH-001 is a VP.Start IoT solution designed to control the on / off switch in the \nhome via AlienCheck App . You can manage your home lighting anytime, \nanywhere, even though you are away from home.', '1.0\nVH-004\nVP.Start\nHome  Vision\nApplic ation\nKey Feature s\nTechn ical Speciﬁc ation\nInput  Volta ge\n200 to 240 (VAC),    10%\nFre quenc y\n50Hz\nOutput  Voltag e\n200 to 240 (VAC),    10%\nIns tallat ion \nOpe ration Temper ature Ran ge\n0 ºC - 65 ºC\nMount with pattress box\nCommunic ation\nWiﬁ 2.4GHz, Protocol 802.11 b/g/n\nSAFETY & SECURITY\nMODERN & COMFORT\nCOMSUMPTION\nOPERATION & MAINTENANCE\nThe VH-004 is a touch switch which has the capability to control the On/Off switch']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[{'chunk_index': 13, 'title': 'iot-leaflet-v10-en.pdf'}, {'chunk_index': 8, 'title': 'iot-leaflet-v10-en.pdf'}, {'title': 'iot-leaflet-v10-en.pdf', 'chunk_index': 15}]], 'distances': [[177.2965545654297, 185.19163513183594, 188.01963806152344]]}

# %% [markdown]
# ### Log collect database ###

# %%
# List all collections
collections = client.list_collections()

# Print collection names
for col in collections:
    print(col.name)
# Out:
# pdf_docs

# %% [markdown]
# ### Delete Collection database ###

# %%
client.delete_collection(name="pdf_docs")

# %%
all_data = collection.get()

print(all_data)
# Out:
# {'ids': ['ec121ad2', 'ec122702', 'ec122770', 'ec1227ac', 'ec1227d4', 'ec1227fc', 'ec122824', 'ec12284c', 'ec122874', 'ec12289c', 'ec1228ba', 'ec1228e2', 'ec12290a', 'ec122932', 'ec122950', 'ec122978', 'ec122996', 'ec1229be', 'ec1229dc', 'ec122a04', 'ec122a22', '7b294540', '7b29482e', '7b294860', '7b29487e', '10267efc', '102684e2', '10268532', '1026855a', '10268582', '102685a0', '102685be', '102685dc', '102685fa', '1026860e', '1026862c', '1026864a', '1026865e', '1026867c', '1026869a', '102686ae', '102686cc', '102686ea', '102686fe', '1026871c', '1026873a', '1026874e', '1026876c', '1026878a', '1026879e', '102687bc', '102687da', '102687ee', '1026880c', '10268820', '1026883e', '10268852', '10268870', '1026888e', '102688ac', '102688c0', '102688de', '102688fc', '10268910', '1026892e', '1026894c', '10268960', '1026897e', '1026899c', '102689b0', '102689ce', '102689ec', '10268a00', '10268a1e', '10268a3c', '10268a50', '10268a6e', '10268a82', '10268aa0', '10268abe', '10268ad2', '10268af0', '10268b04', '10268b22', '10268b40', '10268b54', '10268b72', '10268b86', '10268ba4', '10268bc2', '10268be0', '10268bfe', '10268c12', '10268c30', '10268c4e', '10268c62', '10268c80', '10268c94', '10268cb2', '10268cc6', '10268ce4', '10268cf8', '10268d20', '10268d3e', '10268d5c', '10268d70', '10268d8e', '10268da2', '10268dc0', '10268dd4', '10268df2', '10268e10', '10268e24', '10268e42', '10268e56', '10268e74', '10268e88', '10268ea6', '10268ec4', '10268ee2', '10268ef6', '10268f14', '10268f28'], 'embeddings': None, 'documents': ["VP.START TECHNOLOGY Co.,LTD\nInnovation Through Technology\n023 888 167 / 086 6666 77 VP.Start\n1.0\nSmart Grid\nOur key points of developing IoT solutions are security and\nsaf ety st orage, connectivity and Alien Check. \nWhat  are  VP.Start 's\nIoT solutions differe nt\nfrom ot hers?  \nsecurity and saf ety st orage\nDescription\nAs of now, the entire world communicates through the Internet, and technology certainly has a big role to play", 'in the matter. For most of us, digital technology has entered our homes through computers and smartphones; \nnowadays, technology is ready to rule every aspect of our home. It is the reason that VP.Start developing the \nHome Vision Automation device to make a home int elligent, comfortable and secure.\nHome Vision is very comfortable to live in. With smart devices, your home becomes your buddy. You are never \nreally alone. Your home becomes your company.', 'really alone. Your home becomes your company. \nImagine returning to a home that takes care of your comfort and ensures you remain safe. What’s more, smart \nhomes are safer and more secure compared to ordinary homes.\nThe Introduc tion of VP.Start Alien Check IoT\n“Mapping Automation”\n“Safety & Security, Modern & Comfort,\n Comsumption, Operation and Maintenance”   \nVP.Start\nHome Vision\nVP.START TECHNOLOGY Co.,LTD\nInnovation Through Technology\n023 888 167 / 086 6666 77 VP.Start\n1.0\nPlug and Play', '1.0\nPlug and Play\nOur IoT devices are a very simple installation; you only \npower off the electricity in your home and just simply \ninstall or mount the IoT devices to upgrade your old \nhome appliances to be a smart one. After ﬁnishing the \ninstallation and turning on the electricity, your smart \ndevice starts working. You just add a smart device into \nAlienCheck.\nVP.Start  Cloud\nOur Cloud server was built in Cambodia. We store data \nusers in our cloud by keeping your data safe and', 'users in our cloud by keeping your data safe and \nsecured. The words of safety, security, and integrity are \nan integral part of our Services. \nVP.Start Bridge\nThe ability controls directly or by smartphone, track \ninformation, receive anomalies, and scheduling \nautomation, are introduced by many VP.Start IoTs, not \nonly our engineers enable the connectivity function, \nwhich will allow IoTs can talk to each other. Through \nVP.Start Bridge, users will experience entirely Home', 'Automation bringing all home devices/appliances \nshall be a ...

# %% [markdown]
# ### Query data from database ###

# %%
# 1. User question
question = "ប្រទេសកម្ពុជា មានរាជធានីអ្វី?"

# 2. Embed question
q_vector = embeddings.embed_query(question)

# 3. Search in ChromaDB
results = collection.query(
    query_embeddings=[q_vector],
    n_results=5
)

# print("search in chromaDB:",results)

# 4. Combine retrieved chunks
context = results
print(context)
# Out:
# {'ids': [['3', '1', '0', '7b29487e', '10268f28']], 'embeddings': None, 'documents': [['កម្ពុជាមានជំរុំទេសចរណ៍ធម្មជាតិ។\nទន្លេសាបផ្លាស់ប្តូរទិសហូរ។\nប្រជាជនកម្ពុជា មានទម្លាប់គោរពអ្នកចាស់។\nកម្ពុជាមានប្រាសាទរាប់ពាន់។\nពិធីបុណ្យចូលឆ្នាំខ្មែរ មានរយៈពេលបីថ្ងៃ។\nអង្គរវត្តបង្ហាញសិល្បៈខ្មែរបុរាណ។\nកម្ពុជា មានប្រព័ន្ធកសិកម្មទឹកភ្លៀង។\nភ្នំពេញ មានស្ពានជាច្រើន។\nប្រជាជនកម្ពុជាមានអារម្មណ៍សប្បាយរីករាយ។', 'កម្ពុជា មានព្រៃឈើធម្មជាតិដ៏សម្បូរបែប។\nទេសភាពភ្នំកោដៃស្រស់ស្អាត។\nពិធីបុណ្យអុំទូក មានល្បែងប្រណាំងទូក។\nភ្នំពេញមានអគារលំដាប់បីសម័យ។\nកម្ពុជាមានអាកាសធាតុក្តៅសើម។\nអង្គរធំ មានតំបន់ជុំវិញធំជាងគេ។\nភោជនីយដ្ឋានខ្មែរបម្រើម្ហូបបែបប្រពៃណី។\nប្រាសាទព្រះវិហារ ស្ថិតនៅលើភ្នំ។\nប្រទេសកម្ពុជាមានប្រជាជនលើសពី ១៦ លាននាក់។\nទេសចរណ៍អន្តរជាតិចូលមកកម្ពុជា។\nភ្នំពេញមានសារមន្ទីរជាតិ។\nកម្ពុជាមានសិល្បៈរបាំអប្សរា។\nអ្នកស្រុកកាន់ពិធីបុណ្យភ្ជុំបិណ្ឌ។\nកម្ពុជា មានព្រំដែនជាមួយថៃ និងវៀតណាម។\nប្រជាជនខ្មែរចូលចិត្តលេងកីឡាបាល់ទាត់។', 'ប្រទេសកម្ពុជា មានរាជធានីភ្នំពេញ។\nអង្គរវត្ត ជាសម្បត្តិវប្បធម៌ពិភពលោក។\nទន្លេមេគង្គហូរឆ្លងកាត់កម្ពុជា។\nប្រាសាទបាយ័ន មានមុខថ្មជាច្រើន។\nតំបន់ទេសចរណ៍សៀមរាបទាក់ទាញភ្ញៀវច្រើន។\nអាហារខ្មែរ មានរសជាតិឆ្ងាញ់។\nអម្ចាស់ប្រទេសកម្ពុជា គឺព្រះមហាក្សត្រ។\nប្រជាជនខ្មែរ ចូលចិត្តញ៉ាំអាម៉ុកត្រី។\nប្រាសាទតាព្រហ្ម មានឈើធំៗព័ទ្ធជុំវិញ។\nទន្លេសាប ជាបឹងទឹកសាបធំបំផុតនៅអាស៊ីអាគ្នេយ៍។\nប្រាសាទភ្នំបាគង ជាប្រាសាទថ្មចាស់។\nកម្ពុជាមានចំណុចប្រវត្តិសាស្ត្រច្រើន។\nភាសាផ្លូវការរបស់កម្ពុជា គឺភាសាខ្មែរ។\nកម្ពុជា មានព្រៃឈើធម្មជាតិដ៏សម្បូរបែប។', 'Operators can ﬁnd the \nissued location fast and \nperform the action rapidly.', '3D View\n42\nVP-DOC-CTL-DRCs-V1.1\nwww.vpstart.com\n#15, Street 604, Sangkat Boeung Kok 2, Khan Toul Kork, Phnom Penh, 120408, Cambodia.\n#29, Street 1946, Sangkat Phom Penh Thmey, Khan Sen Sok, Phnom Penh, 120408, Cambodia.\n(+855) 23 888 167 / 86 666 677 / 98 555 589\nsale@vpstart.com / info@vpstart.com']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[{'title': 'khmer_text', 'chunk_index': 3, 'type': 'txt'}, {'title': 'khmer_text', 'chunk_index': 1, 'type': 'txt'}, {'type': 'txt', 'title': 'khmer_text', 'chunk_index': 0}, {'chunk_index': 3, 'title': 'nitelite-leaflet-v10-en.pdf'}, {'chunk_index': 97, 'title': 'drc-catalogues-v11-english-210722.pdf'}]], 'distances': [[62.88164138793945, 75.31166076660156, 79.01527404785156, 254.54092407226562, 256.62896728515625]]}

# %%
prompt = f"You are aliencheckbot and a question-answering assistant. Answer briefly,short and accurately.using the following context:\n\n{context}\n\nQuestion: {question}.If you don't know the answer, say 'I don't know.'"
answer = llm(prompt)

print("Answer:", answer)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 2
#       1 prompt = f"You are aliencheckbot and a question-answering assistant. Answer briefly,short and accurately.using the following context:\n\n{context}\n\nQuestion: {question}.If you don't know the answer, say 'I don't know.'"
# ----> 2 answer = llm(prompt)
#       4 print("Answer:", answer)
#
# File /usr/local/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:193, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     191     warned = True
#     192     emit_warning()
# --> 193 return wrapped(*args, **kwargs)
#
# File /usr/local/lib/python3.10/site-packages/langchain_core/language_models/llms.py:1347, in BaseLLM.__call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#    1340     msg = (
#    1341         "Argument `prompt` is expected to be a string. Instead found "
#    1342         f"{type(prompt)}. If you want to run the LLM on multiple prompts, use "
#    1343         "`generate` instead."
#    1344     )
#    1345     raise ValueError(msg)  # noqa: TRY004
#    1346 return (
# -> 1347     self.generate(
#    1348         [prompt],
#    1349         stop=stop,
#    1350         callbacks=callbacks,
#    1351         tags=tags,
#    1352         metadata=metadata,
#    1353         **kwargs,
#    1354     )
#    1355     .generations[0][0]
#    1356     .text
#    1357 )
#
# File /usr/local/lib/python3.10/site-packages/langchain_core/language_models/llms.py:1000, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     985 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     986     run_managers = [
#     987         callback_manager.on_llm_start(
#     988             self._serialized,
#    (...)
#     998         )
#     999     ]
# -> 1000     return self._generate_helper(
#    1001         prompts,
#    1002         stop,
#    1003         run_managers,
#    1004         new_arg_supported=bool(new_arg_supported),
#    1005         **kwargs,
#    1006     )
#    1007 if len(missing_prompts) > 0:
#    1008     run_managers = [
#    1009         callback_managers[idx].on_llm_start(
#    1010             self._serialized,
#    (...)
#    1017         for idx in missing_prompt_idxs
#    1018     ]
#
# File /usr/local/lib/python3.10/site-packages/langchain_core/language_models/llms.py:815, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     804 def _generate_helper(
#     805     self,
#     806     prompts: list[str],
#    (...)
#     811     **kwargs: Any,
#     812 ) -> LLMResult:
#     813     try:
#     814         output = (
# --> 815             self._generate(
#     816                 prompts,
#     817                 stop=stop,
#     818                 # TODO: support multiple run managers
#     819                 run_manager=run_managers[0] if run_managers else None,
#     820                 **kwargs,
#     821             )
#     822             if new_arg_supported
#     823             else self._generate(prompts, stop=stop)
#     824         )
#     825     except BaseException as e:
#     826         for run_manager in run_managers:
#
# File /usr/local/lib/python3.10/site-packages/langchain_community/llms/ollama.py:437, in Ollama._generate(self, prompts, stop, images, run_manager, **kwargs)
#     435 generations = []
#     436 for prompt in prompts:
# --> 437     final_chunk = super()._stream_with_aggregation(
#     438         prompt,
#     439         stop=stop,
#     440         images=images,
#     441         run_manager=run_manager,
#     442         verbose=self.verbose,
#     443         **kwargs,
#     444     )
#     445     generations.append([final_chunk])
#     446 return LLMResult(generations=generations)
#
# File /usr/local/lib/python3.10/site-packages/langchain_community/llms/ollama.py:349, in _OllamaCommon._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     340 def _stream_with_aggregation(
#     341     self,
#     342     prompt: str,
#    (...)
#     346     **kwargs: Any,
#     347 ) -> GenerationChunk:
#     348     final_chunk: Optional[GenerationChunk] = None
# --> 349     for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     350         if stream_resp:
#     351             chunk = _stream_response_to_generation_chunk(stream_resp)
#
# File /usr/local/lib/python3.10/site-packages/langchain_community/llms/ollama.py:194, in _OllamaCommon._create_generate_stream(self, prompt, stop, images, **kwargs)
#     186 def _create_generate_stream(
#     187     self,
#     188     prompt: str,
#    (...)
#     191     **kwargs: Any,
#     192 ) -> Iterator[str]:
#     193     payload = {"prompt": prompt, "images": images}
# --> 194     yield from self._create_stream(
#     195         payload=payload,
#     196         stop=stop,
#     197         api_url=f"{self.base_url}/api/generate",
#     198         **kwargs,
#     199     )
#
# File /usr/local/lib/python3.10/site-packages/langchain_community/llms/ollama.py:252, in _OllamaCommon._create_stream(self, api_url, payload, stop, **kwargs)
#     246 else:
#     247     request_payload = {
#     248         "prompt": payload.get("prompt"),
#     249         "images": payload.get("images", []),
#     250         **params,
#     251     }
# --> 252 response = requests.post(
#     253     url=api_url,
#     254     headers={
#     255         "Content-Type": "application/json",
#     256         **(self.headers if isinstance(self.headers, dict) else {}),
#     257     },
#     258     auth=self.auth,
#     259     json=request_payload,
#     260     stream=True,
#     261     timeout=self.timeout,
#     262 )
#     263 response.encoding = "utf-8"
#     264 if response.status_code != 200:
#
# File /usr/local/lib/python3.10/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File /usr/local/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /usr/local/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /usr/local/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /usr/local/lib/python3.10/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File /usr/local/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File /usr/local/lib/python3.10/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /usr/local/lib/python3.10/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File /usr/local/Cellar/python@3.10/3.10.18/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /usr/local/Cellar/python@3.10/3.10.18/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/local/Cellar/python@3.10/3.10.18/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/local/Cellar/python@3.10/3.10.18/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# an example input
input = "who are we at VP.Start"
text = """1. Who are we at VP. Start?
In 2014, a young electrical engineer had some questions. 'What if we had a reliable energy grid in Cambodia?
What if we could solve issues with the grid remotely and immediately? What if we could use our existing
infrastructure, upgrade it affordably?
These questions gave birth to an innovative idea, the SIMA Journey. The engineer gathered a few friends
in a small rented space and they started chasing their dreams, working late nights and weekends and often
packing everything in their car to go to some remote rural locations to test out their ideas. These were the first
steps on the SIMA Journey."""

# generate a response combining the prompt and data we retrieved in step 2
output = ollama.generate(
  model="llama3.2",
  prompt=f"Using this data: {text}. Respond to this prompt: {input}"
)

print(output['response'])
# Out:
# Based on the provided data, it appears that at VP.Start, we are a group of innovators and engineers who came together with a shared vision to create a reliable energy grid in Cambodia. Our mission is to address issues with the existing grid, solve problems remotely, and upgrade our infrastructure in an affordable manner.
#
# From what I understand, our team was founded by a young electrical engineer in 2014, who was driven by questions about how we could improve the energy infrastructure in Cambodia. Since then, we've grown into a dedicated group of like-minded individuals who are passionate about using technology to make a positive impact on our community.
#
# We're currently based in a rented space and have been working tirelessly to bring our vision to life, often putting in long hours and traveling to remote rural locations to test out our ideas. Our journey, dubbed the "SIMA Journey", has just begun, and we're excited to see where it takes us!
